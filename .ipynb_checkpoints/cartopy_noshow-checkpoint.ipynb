# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">AG Dynamics of the Earth</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Jupyter notebooks</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# </tr>
# </table>

# %% [markdown]
# # Dynamical Systems: Cartopy
# ## Plotting maps with `cartopy`
# ----
# *Georg Kaufmann,
# Geophysics Section,
# Institute of Geological Sciences,
# Freie Universität Berlin,
# Germany*

# %%
import matplotlib.pyplot as plt
import numpy as np

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.mpl.ticker as cticker

# %% [markdown]
# ----
# ## Using `Projections`
#
# Global map in Robinson projection, with coastlines added.

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines(color='blue')
plt.title("Robinson Projection")
# Out:
# Text(0.5, 1.0, 'Robinson Projection')
# /opt/miniconda3/envs/python_R/lib/python3.10/site-packages/shapely/constructive.py:181: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(

# %% [markdown]
# ----
# ## Using `gridlines`
#
# Add gridlines to map.

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines(color='blue')
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False,color='black')
plt.title("Robinson Projection")
# Out:
# Text(0.5, 1.0, 'Robinson Projection')

# %% [markdown]
# ----
# ## Using `features`
#
# Add a land-ocean mask, draw coastlines, and add lakes and rivers.

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.Robinson())
ax.add_feature(cfeature.LAND,color='green')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE,color='black')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS,color='blue')
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False,color='black')
plt.title("Robinson Projection")
# Out:
# Text(0.5, 1.0, 'Robinson Projection')
# /opt/miniconda3/envs/python_R/lib/python3.10/site-packages/shapely/constructive.py:181: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /opt/miniconda3/envs/python_R/lib/python3.10/site-packages/shapely/constructive.py:181: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /opt/miniconda3/envs/python_R/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ----
# ## Change `extent`

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-10, 10, 45, 60])
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False,color='black')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE,color='black')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS,color='blue')
plt.title("PlateCarree Projection")
# Out:
# Text(0.5, 1.0, 'PlateCarree Projection')
# /opt/miniconda3/envs/python_R/lib/python3.10/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %% [markdown]
# ----
# ## Add custom labels

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-10, 10, 45, 60])
ax.set_xticks([-8,-6,-4,-2,0,2,4,6,8])
ax.set_yticks([46,48,50,52,54,56,58])
lon_formatter = cticker.LongitudeFormatter(number_format='.1f',zero_direction_label=True)
lat_formatter = cticker.LatitudeFormatter(number_format='.1f')
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
ax.gridlines(draw_labels=False,linewidth=1, color='gray', alpha=0.5, linestyle='--')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE,color='black')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS,color='blue')
plt.title("PlateCarree Projection")
# Out:
# Text(0.5, 1.0, 'PlateCarree Projection')

# %% [markdown]
# ----
# ## Add background image
#
# Use the standard image in `cartopy`.

# %%
from cartopy.io.img_tiles import GoogleTiles
from cartopy.io.img_tiles import Stamen
#from cartopy.io.srtm import srtm_composite

fig = plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-10, 10, 45, 60])
ax.set_xticks([-8,-6,-4,-2,0,2,4,6,8])
ax.set_yticks([46,48,50,52,54,56,58])
lon_formatter = cticker.LongitudeFormatter(number_format='.1f',zero_direction_label=True)
lat_formatter = cticker.LatitudeFormatter(number_format='.1f')
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
ax.gridlines(draw_labels=False,linewidth=1, color='gray', alpha=0.5, linestyle='--')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE,color='black')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS,color='blue')

ax.stock_img()

plt.title("PlateCarree Projection")
# Out:
# Text(0.5, 1.0, 'PlateCarree Projection')

# %% [markdown]
# ----
# ## Add `srtm` data as (shaded) relief

# %% [raw]
# missing

# %% [markdown]
# ... done
